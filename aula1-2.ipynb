# %% [markdown]
# <a href="https://colab.research.google.com/github/murillokossobuski/INTROML-dell-lead/blob/main/%5BINTROML%5D_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# dados registrados

# %%
temperatura = np.array([30,25,36,18,25,29,12,13,14,32,34])

# %%
numero_sorvetes = np.array ([20,15,45,10,20,23,6,9,12,34,28])

# %%
df = pd.DataFrame({'temperatura': temperatura, 'numero_sorvetes': numero_sorvetes})

# %%
df.head()
# Out:
#    temperatura  numero_sorvetes
# 0           30               20
# 1           25               15
# 2           36               45
# 3           18               10
# 4           25               20

# %% [markdown]
# gerando graficos

# %%
plt.plot(df['temperatura'], df['numero_sorvetes'], '*')
plt.xlabel('temperatura')
plt.ylabel('numero_sorvetes')
plt.title('temperatura x numero_sorvetes')
plt.show()

# %% [markdown]
# variaveis independentes e dependentes

# %%
x = df['temperatura'].to_numpy() #converte o datadframe p float
y = df['numero_sorvetes'].to_numpy()
from sklearn.model_selection import train_test_split #80% treinar e 20% testar se ta certo
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# treinando o modelo

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()
modelo.fit(x_treino.reshape(-1,1), y_treino.reshape(-1,1))
# Out:
# LinearRegression()

# %% [markdown]
# previsões

# %%
y_previsto = modelo.predict(x_teste.reshape(-1,1))

# %%
plt.plot(range(y_previsto.shape[0]), y_previsto, 'r--')
plt.plot(range(y_teste.shape[0]), y_teste, 'g--')
plt.legend(['Sorvetes previstos', 'Sorvetes vendidos'])
plt.xlabel('índice')
plt.ylabel('Sorvetes')
plt.show()
