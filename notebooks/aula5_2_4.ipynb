# %%
from sklearn.neural_network import MLPRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# from sklearn.datasets import load_boston

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_2348/3257800236.py:5: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %%
X = data
y = target

print(f"Shape de X: {X.shape}")
print(f"Shape de y: {y.shape}")
# Out:
# Shape de X: (506, 13)
# Shape de y: (506,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# é uma boa usar min max em redes neurais, elas se beneficiam de datasets com escalas parecidas

# %%
mm = MinMaxScaler()
X_train = mm.fit_transform(X_train)
X_test = mm.transform(X_test)

# %%
mlp = MLPRegressor(hidden_layer_sizes=(100,100,50,50), max_iter = 1000) # num de neuronios

# %%
mlp.fit(X_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(100, 100, 50, 50), max_iter=1000)

# %%
mlp.score (X_test, y_test)
# Out:
# 0.8321703824925312
